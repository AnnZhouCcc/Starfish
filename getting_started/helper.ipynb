# %%
# generate conf files to run
conffile = f'run.conf'

# dringwcmpecmp
stime = 100 # ms
nlinks = 2132
nhosts = 2988
bw = 1342176000 # B per second
load_list = [1]
seed_list = [1]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 1
topologyfile = '../detailed_ae/evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../detailed_ae/evalserverfiles/dring_2988_80_64.sv'
npfile = '../detailed_ae/evalnetpathfiles/netpath_dring_80_64_ecmp.np'
pwfile = 'pathweightfile.pw'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = 'trafficfile.cm'
            outfile = 'outfile.out'
            f.write(f"../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfile} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
