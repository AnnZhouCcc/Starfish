# %%
# generate conf files to run
conffile = "run.conf"

# dringsu2
stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11)
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_su2.np'
oversub_list = [0.33,0.67,1.33,1.67]

with open(conffile, 'a') as f:
    for oversub in oversub_list:
        for seed in seed_list:
            for load in load_list:
                cmfile = f'../main/enp/cmfiles/dring_load{load}.cm'
                pwfileprefix = f'../main/enp/pwfiles/pathweight_dring_su2_prv1_load{load}_interval'
                outfile = f'outfiles/dringsu2_oversub{oversub}_load{load}_seed{seed}.out'
                f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} -os_ratio {oversub} > {outfile}\n")


# leafspine
stime = 144 # ms
nlinks = 2048
nhosts = 3072
bw = 1342176000 # B per second
load_list = range(1,11)
seed_list = [1,2,3,4,5]
topologytype = 1
nswitches = 80
os = 1
k = 64
nintervals = 1
npfile = '../evalnetpathfiles/netpath_leafspine_80_64_ecmp.np'
pwfile = '../main/enp/pwfiles/pathweight_leafspine.pw'
oversub_list = [0.33,0.67,1.33,1.67]

with open(conffile, 'a') as f:
    for oversub in oversub_list:
        for seed in seed_list:
            for load in load_list:
                cmfile = f'../main/enp/cmfiles/leafspine_load{load}.cm'
                outfile = f'outfiles/leafspine_oversub{oversub}_load{load}_seed{seed}.out'
                f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfile} -numintervals {nintervals} -os_ratio {oversub} > {outfile}\n")
