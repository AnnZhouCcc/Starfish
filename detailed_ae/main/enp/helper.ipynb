# %%
# generate conf files to run
conffile = f'run.conf'

# dringsu2
stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_su2.np'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_dring_su2_prv1_load{load}_interval'
            outfile = f'enp/outfiles/dringsu2_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")

# dringsu2e
stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 1
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_su2.np'
pwfile = '../evalotherpathweightfiles/pathweight_dring_80_64_su2e.pw'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            # pwfileprefix = f'experiments/nsdi26fall/eval_main/unv1/pwfiles/pathweight_dring_su2_unv1_load{load}_interval'
            outfile = f'enp/outfiles/dringsu2e_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfile} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            
# ls
stime = 144 # ms
nlinks = 2048
nhosts = 3072
bw = 1342176000 # B per second
load_list = range(1,11) #[10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 1
nswitches = 80
os = 1
k = 64
nintervals = 1
npfile = '../evalnetpathfiles/netpath_leafspine_80_64_ecmp.np'
pwfile = 'enp/pwfiles/pathweight_leafspine.pw'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/leafspine_load{load}.cm'
            outfile = f'enp/outfiles/leafspine_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfile} -numintervals {nintervals} > {outfile}\n")
            

# rrgsu2
stime = 144 # ms
nlinks = 2048 # 1024*2, uni-directional
nhosts = 3072
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/rrg_80_64.edgelist'
serverfile = '../evalserverfiles/rrg_3072_80_64.sv'
npfile = '../evalnetpathfiles/netpath_rrg_80_64_su2.np'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/rrg_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_rrg_su2_prv1_load{load}_interval'
            outfile = f'enp/outfiles/rrgsu2_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            
# df2augalg
p = 40
a = 2
h = 19

topologyfile = f"../evaltopologyfiles/df_p{p}_a{a}_h{h}.edgelist"
serverfile = f"../evalserverfiles/df_p{p}_a{a}_h{h}.sv"
numsw = a*(a*h+1)
npfile = f"../evalnetpathfiles/netpath_df_p{p}_a{a}_h{h}_augalg.np"

stime = 144 # ms
g = a*h+1
nlinks = a*(a-1)*g + g*(g-1) # uni-directional
nhosts = a*p*g
bw = 1342176000 # B per second
load_list = range(1,11)
seed_list = [1,2,3,4,5]
topologytype = 3
nswitches = a*g
k = p+h+a-1 # nports
os = 1 #unused
nintervals = 8

# print(f"#switches: {numsw}, #servers: {nhosts}, #links: {nlinks}, #groups: {g}, #ports: {k}")

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/df2_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_df2_augalg_prv1_load{load}_interval'
            outfile = f'enp/outfiles/df2augalg_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -df_p {p} -df_a {a} -df_h {h} -cmfile {cmfile} -topologytype {topologytype} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            

# dringecmp
stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_ecmp.np' 

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_dring_ecmp_prv1_load{load}_interval'
            outfile = f'enp/outfiles/dringecmp_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            

# dringwcmpecmp
stime = 144 # ms
nlinks = 2132
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) #[10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 1
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_ecmp.np'
pwfile = 'enp/pwfiles/pathweight_dring_wcmp_ecmp.pw'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            outfile = f'enp/outfiles/dringwcmpecmp_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfile} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            
            
# dringfatpaths
stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_fatpaths.np'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_dring_fatpaths_prv1_load{load}_interval'
            outfile = f'enp/outfiles/dringfatpaths_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            

# dringfhi
stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_fhi.np'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_dring_fhi_prv1_load{load}_interval'
            outfile = f'enp/outfiles/dringfhi_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            

# dringracke1four            
stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_racke1four.np'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_dring_racke1four_prv1_load{load}_interval'
            outfile = f'enp/outfiles/dringracke1four_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")

# %%
# generate expected fct summary files
prevfctfile = "../../../../DRing/src/emp/datacentre/experiments/nsdi26fall/eval_main/fct_summary.txt"
myfctfile = "expected_fct_summary.txt"
with open(prevfctfile, 'r') as fprev, open(myfctfile, 'w') as fmy:
    lines = fprev.readlines()
    for line in lines:
        if "prv1" in line:
            fmy.write(line)

# %%
# generate conf files to run
conffile = f'quickrun.conf'

# dringsu2
stime = 2 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_su2.np'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_dring_su2_prv1_load{load}_interval'
            outfile = f'enp/outfiles/dringsu2_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")

# dringsu2e
# stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 1
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_su2.np'
pwfile = '../evalotherpathweightfiles/pathweight_dring_80_64_su2e.pw'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            # pwfileprefix = f'experiments/nsdi26fall/eval_main/unv1/pwfiles/pathweight_dring_su2_unv1_load{load}_interval'
            outfile = f'enp/outfiles/dringsu2e_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfile} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            
# ls
# stime = 144 # ms
nlinks = 2048
nhosts = 3072
bw = 1342176000 # B per second
load_list = range(1,11) #[10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 1
nswitches = 80
os = 1
k = 64
nintervals = 1
npfile = '../evalnetpathfiles/netpath_leafspine_80_64_ecmp.np'
pwfile = 'enp/pwfiles/pathweight_leafspine.pw'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/leafspine_load{load}.cm'
            outfile = f'enp/outfiles/leafspine_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfile} -numintervals {nintervals} > {outfile}\n")
            

# rrgsu2
# stime = 144 # ms
nlinks = 2048 # 1024*2, uni-directional
nhosts = 3072
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/rrg_80_64.edgelist'
serverfile = '../evalserverfiles/rrg_3072_80_64.sv'
npfile = '../evalnetpathfiles/netpath_rrg_80_64_su2.np'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/rrg_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_rrg_su2_prv1_load{load}_interval'
            outfile = f'enp/outfiles/rrgsu2_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            
# df2augalg
p = 40
a = 2
h = 19

topologyfile = f"../evaltopologyfiles/df_p{p}_a{a}_h{h}.edgelist"
serverfile = f"../evalserverfiles/df_p{p}_a{a}_h{h}.sv"
numsw = a*(a*h+1)
npfile = f"../evalnetpathfiles/netpath_df_p{p}_a{a}_h{h}_augalg.np"

# stime = 144 # ms
g = a*h+1
nlinks = a*(a-1)*g + g*(g-1) # uni-directional
nhosts = a*p*g
bw = 1342176000 # B per second
load_list = range(1,11)
seed_list = [1,2,3,4,5]
topologytype = 3
nswitches = a*g
k = p+h+a-1 # nports
os = 1 #unused
nintervals = 8

# print(f"#switches: {numsw}, #servers: {nhosts}, #links: {nlinks}, #groups: {g}, #ports: {k}")

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/df2_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_df2_augalg_prv1_load{load}_interval'
            outfile = f'enp/outfiles/df2augalg_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -df_p {p} -df_a {a} -df_h {h} -cmfile {cmfile} -topologytype {topologytype} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            

# dringecmp
# stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_ecmp.np' 

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_dring_ecmp_prv1_load{load}_interval'
            outfile = f'enp/outfiles/dringecmp_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            

# dringwcmpecmp
# stime = 144 # ms
nlinks = 2132
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) #[10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 1
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_ecmp.np'
pwfile = 'enp/pwfiles/pathweight_dring_wcmp_ecmp.pw'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            outfile = f'enp/outfiles/dringwcmpecmp_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfile} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            
            
# dringfatpaths
# stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_fatpaths.np'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_dring_fatpaths_prv1_load{load}_interval'
            outfile = f'enp/outfiles/dringfatpaths_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            

# dringfhi
# stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_fhi.np'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_dring_fhi_prv1_load{load}_interval'
            outfile = f'enp/outfiles/dringfhi_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
            

# dringracke1four            
# stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
load_list = range(1,11) # [10,30,50,70]
seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_racke1four.np'

with open(conffile, 'a') as f:
    for seed in seed_list:
        for load in load_list:
            cmfile = f'enp/cmfiles/dring_load{load}.cm'
            pwfileprefix = f'enp/pwfiles/pathweight_dring_racke1four_prv1_load{load}_interval'
            outfile = f'enp/outfiles/dringracke1four_load{load}_seed{seed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} > {outfile}\n")
