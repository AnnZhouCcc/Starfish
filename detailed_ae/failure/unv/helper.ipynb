# %%
# generate conf files to run
conffile = f'run.conf'


# dringsu2 before
stime = 144 # ms
nlinks = 2132 # 1066*2, uni-directional
nhosts = 2988
bw = 1342176000 # B per second
# load_list = range(1,11) # [10,30,50,70]
# seed_list = [1,2,3,4,5]
topologytype = 2
nswitches = 80
os = 1
k = 64
nintervals = 8
topologyfile = '../evaltopologyfiles/dring_80_64.edgelist'
serverfile = '../evalserverfiles/dring_2988_80_64.sv'
npfile = '../evalnetpathfiles/netpath_dring_80_64_su2.np'
failpct_list = range(2,11,2)
load = 2
seed = 1
failseed_list = range(10)

cmfile = f'../main/unv/cmfiles/dring_load{load}.cm'

pwfileprefix = f'unv/pwfiles/pathweight_dring_su2_unv1_before_load{load}_interval'
with open(conffile, 'a') as f:
    for failpct in failpct_list:
        numfaillinks = int(nlinks * failpct / 100)
        for failseed in failseed_list:
            linkfailurefile = f"linkfailurefiles/dring_{numfaillinks}_{failseed}.lf"
            outfile = f'unv/outfiles/dringsu2_before_nfaillinks{numfaillinks}_fseed{failseed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} -numfaillinks {numfaillinks} -linkfailurefile {linkfailurefile} > {outfile}\n")


# dringsu2 after
with open(conffile, 'a') as f:
    for failpct in failpct_list:
        numfaillinks = int(nlinks * failpct / 100)
        for failseed in failseed_list:
            linkfailurefile = f"linkfailurefiles/dring_{numfaillinks}_{failseed}.lf"
            pwfileprefix = f'unv/pwfiles/pathweight_dring_su2_unv1_nfaillinks{numfaillinks}_fseed{failseed}_load{load}_interval'
            outfile = f'unv/outfiles/dringsu2_after_nfaillinks{numfaillinks}_fseed{failseed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfileprefix} -numintervals {nintervals} -serverfile {serverfile} -topologyfile {topologyfile} -numfaillinks {numfaillinks} -linkfailurefile {linkfailurefile} > {outfile}\n")
            

# leafspine  
stime = 144 # ms
nlinks = 2048
nhosts = 3072
bw = 1342176000 # B per second
# load_list = range(1,11) #[10,30,50,70]
# seed_list = [1,2,3,4,5]
topologytype = 1
nswitches = 80
os = 1
k = 64
nintervals = 1
npfile = '../evalnetpathfiles/netpath_leafspine_80_64_ecmp.np'
pwfile = 'unv/pwfiles/pathweight_leafspine.pw'
failpct_list = range(2,11,2)
load = 2
seed = 1
failseed_list = range(10)    

cmfile = f'../main/unv/cmfiles/leafspine_load{load}.cm'

with open(conffile, 'a') as f:
    for failpct in failpct_list:
        numfaillinks = int(nlinks * failpct / 100)
        for failseed in failseed_list:
            linkfailurefile = f"linkfailurefiles/leafspine_{numfaillinks}_{failseed}.lf"
            outfile = f'unv/outfiles/leafspine_before_nfaillinks{numfaillinks}_fseed{failseed}.out'
            f.write(f"../../src/emp/datacentre/eval -stime {stime} -seed {seed} -cmfile {cmfile} -topologytype {topologytype} -numswitches {nswitches} -numhosts {nhosts} -os {os} -ls_k {k} -npfile {npfile} -pwfileprefix {pwfile} -numintervals {nintervals} -numfaillinks {numfaillinks} -linkfailurefile {linkfailurefile} > {outfile}\n")
