# %%
# generate bash script to copy outfiles
# cd detailed_ae/
# cp main/unv/outfiles/dringsu2_load3_seed1.out cdf/outfiles/
# cd detailed_ae/cdf/
# tar -cvJf outfilesdir.tar.xz outfiles/
for fname in ["unv","enp"]:
    for scheme in ["dringsu2","dringsu2e","leafspine","dringfhi"]:
        print(f'cp main/{fname}/outfiles/{scheme}_load3_seed1.out cdf/outfiles/{fname}_{scheme}_load3_seed1.out')
# Out:
# cp main/unv/outfiles/dringsu2_load3_seed1.out cdf/outfiles/unv_dringsu2_load3_seed1.out
# cp main/unv/outfiles/dringsu2e_load3_seed1.out cdf/outfiles/unv_dringsu2e_load3_seed1.out
# cp main/unv/outfiles/leafspine_load3_seed1.out cdf/outfiles/unv_leafspine_load3_seed1.out
# cp main/unv/outfiles/dringfhi_load3_seed1.out cdf/outfiles/unv_dringfhi_load3_seed1.out
# cp main/enp/outfiles/dringsu2_load3_seed1.out cdf/outfiles/enp_dringsu2_load3_seed1.out
# cp main/enp/outfiles/dringsu2e_load3_seed1.out cdf/outfiles/enp_dringsu2e_load3_seed1.out
# cp main/enp/outfiles/leafspine_load3_seed1.out cdf/outfiles/enp_leafspine_load3_seed1.out
# cp main/enp/outfiles/dringfhi_load3_seed1.out cdf/outfiles/enp_dringfhi_load3_seed1.out
